# %%
# python libraries imports
import pandas as pd
import pycaret
from pycaret.classification import *

# %%
# Load data
events = pd.read_csv('events_lists/opf100B2.csv',delimiter=';')

# Display to check importation
events.head()
# Out:
#    Frame         Start  Size    Volume    Height        X        Y  MaxX  \
# 0      1  1.625903e+09    14   265.440   59.8567  140.812  21.2103   141
# 1      1  1.625903e+09    13   217.201   38.8800  128.698  30.7045   127
# 2      1  1.625903e+09    14  1167.320  258.8800  172.493  32.4873   171
# 3      1  1.625903e+09     2   152.699   81.5757    0.000  32.5342     0
# 4      1  1.625903e+09    24   258.786   23.3323  143.591  40.1997   141
#
#    MaxY    Round    Alpha   Length  Linearity       Beta       ATAN  \
# 0    21  0.38007  120.120   9.4289    0.88191  46.045260  47.511997
# 1    28  0.35230   62.563  10.2920    0.88131  48.544290  49.998856
# 2    33  0.82503  164.980   5.0883    0.73724  29.236180  30.505383
# 3    33  1.00000   90.000   1.0000    1.00000   6.277236   6.604835
# 4    42  0.32454  145.180  16.6320    0.92202  61.339570  62.558868
#
#        Beta2      LET2        HL       LET       HEA
# 0  59.041197  0.287470  0.064824  0.377448  1.013812
# 1  61.214712  0.220186  0.039414  0.293931  0.635141
# 2  28.934111  2.150760  0.476980  2.117350  8.947225
# 3  20.167436  0.301762  0.161209  0.319338  4.044922
# 4  69.033315  0.194948  0.017577  0.251070  0.337986

# %%
# Import the random forest
rf = load_model('random_forest')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# Predict particle type with random forest classifier
events_classified = predict_model(rf, data=events)
        
#Correct for one-pixels-photons
events_classified.loc[events_classified['Size'] < 2, 'Label'] = 'photon'

# Check 'label' and 'score' column are added
events_classified.head()
# Out:
#    Frame         Start  Size    Volume    Height        X        Y  MaxX  \
# 0      1  1.625903e+09    14   265.440   59.8567  140.812  21.2103   141
# 1      1  1.625903e+09    13   217.201   38.8800  128.698  30.7045   127
# 2      1  1.625903e+09    14  1167.320  258.8800  172.493  32.4873   171
# 3      1  1.625903e+09     2   152.699   81.5757    0.000  32.5342     0
# 4      1  1.625903e+09    24   258.786   23.3323  143.591  40.1997   141
#
#    MaxY    Round    Alpha   Length  Linearity       Beta       ATAN  \
# 0    21  0.38007  120.120   9.4289    0.88191  46.045260  47.511997
# 1    28  0.35230   62.563  10.2920    0.88131  48.544290  49.998856
# 2    33  0.82503  164.980   5.0883    0.73724  29.236180  30.505383
# 3    33  1.00000   90.000   1.0000    1.00000   6.277236   6.604835
# 4    42  0.32454  145.180  16.6320    0.92202  61.339570  62.558868
#
#        Beta2      LET2        HL       LET       HEA   Label   Score
# 0  59.041197  0.287470  0.064824  0.377448  1.013812  photon  0.9922
# 1  61.214712  0.220186  0.039414  0.293931  0.635141  photon  0.9925
# 2  28.934111  2.150760  0.476980  2.117350  8.947225  proton  0.7781
# 3  20.167436  0.301762  0.161209  0.319338  4.044922  photon  0.9998
# 4  69.033315  0.194948  0.017577  0.251070  0.337986  photon  0.9551

# %%
# Save file
file_name = 'events_lists/opf100B0_classified.csv'
events_classified.to_csv(file_name, sep=';')
